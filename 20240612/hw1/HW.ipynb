# %%
import cv2
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content/drive/MyDrive/cv2

# %%
os.chdir('/content/drive/MyDrive/cv2')
os.listdir()
# Out:
# ['myphoto.jpeg', 'myphoto.jpg']

# %%
image1=cv2.imread('myphoto.jpeg')
type(image1)
# Out:
# numpy.ndarray

# %%
from PIL import Image

# %%
print(f"height:{image1.shape[0]} pixels")
print(f"width:{image1.shape[1]} pixels")
print(f"channel:{image1.shape[2]} pixels")
# Out:
# height:410 pixels
# width:308 pixels
# channel:3 pixels

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=RGB size=308x410>

# %%
from PIL import Image

# %%
image2=Image.open('myphoto.jpg')
type(image2)
# Out:
# PIL.MpoImagePlugin.MpoImageFile

# %%
display(image2)
print(image2.size)
# Out:
# <PIL.MpoImagePlugin.MpoImageFile image mode=RGB size=308x410>
# (308, 410)

# %%
width=256
ratio=float(width)/image2.size[0]
height=int(image2.size[1]*ratio)
nim=image2.resize((width,height), Image.BILINEAR)
print(nim.size)
display(nim)
# Out:
# (256, 340)
# <PIL.Image.Image image mode=RGB size=256x340>

# %%
width=512
height=512
nim=image2.resize((width,height), Image.BILINEAR)
print(nim.size)
display(nim)
# Out:
# (512, 512)
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
nim.save('HW1.jpg')
print(nim.mode,nim.format)
display(nim)
# Out:
# RGB None
# <PIL.Image.Image image mode=RGB size=512x512>
